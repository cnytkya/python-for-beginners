# %% [markdown]
# # OOP
# py'da oop(object-oriented programming) veya Türkçe adıyşa Nesne Yönelimli Programlama(NYP), kod yazarken dünyadaki nesneleri modellememizi sağlayan bir programlama yalklaşımıdır.
# ör: bir marketteki tüm ürünleri sanala taşıma yaklaşımı. elma,şeker,şampuan vs. bütün bu ürünleri kayıt altında tutarken veritabanında modelleme yapılır. bu ürünlerin nasıl saklanacağı sorusuna modelleme fikri getirildi. veritabanında bu modellerin karşılığı tablolardır.
#
# 1.class(sınıf) ve object(nesne): sınıf bir taslak nesne ise o taslaktan üretilmiş gerçek bir yapıdır.
# ör: class: "araba" kavramı(properties(özellikler) ya da attribute(nesnenin özellikleri)=> tekerlek,hız,rengi,model,marka vs)
#     nesne: senin garajındaki "Kırmızı BMW" (renk = kırmızı,marka = BMW)
#
# # OOP'nin 4 altın kuralı
# 1.Miras alma(Inheritance): Bir sınıfın özeliklerini,varsa metotlarını başka bişr sınıfa aktarmasıdır. ör: araç sınıfındaki özellikler "motosiklet" sınıfına miras kalabilir.
#
# 2.Soyutlama: karmaşık detayları gizleyip sadecce kullanıcıya gerekli olan kısımları göstermek.

# %%
# 1.Miras alma(Inheritance):
